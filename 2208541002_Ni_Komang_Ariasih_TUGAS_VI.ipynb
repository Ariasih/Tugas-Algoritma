# %% [markdown]
# # ***5.21 Pandas***
# Pandas merupakan Library pada Python yang digunakan pada data analisis.

# %%
#Pemanggilan library Pandas dilakukan karena Pandas menyediakan berbagai fitur dan agar terbaca oleh sistem
#berikut merupakan kode untuk pemanggilan library Pandas
import pandas as pd

# %% [markdown]
# ***5.21.1 Membaca File Data pada Pandas***

# %%
#Memanggil atau Membaca File dengan menggunakan Link (format .csv)
bunga_iris_csv = pd.read_csv("https://raw.githubusercontent.com/imdwipayana/DATA/main/Bunga%20Iris/bunga_iris.csv")
print(bunga_iris_csv)
#Langkah-langkah membaca file menggunakan link
#Pertama, buat variabel nama data. Misalkan 'bunga_iris_csv'
#Kedua, buat code pd.read_(jenis file). Jenis File disini kita bisa gunakan jenis .csv, .txt, ataupun .xlsx
#Selanjutnya copy link raw dari umber data. 
#data dijalankan dengan perintah print
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
#Memanggil atau Membaca File dalam Folder yang Sama
#Langkah-langkah membaca data dalam folder yang sama
#Pertama,simpan data dalam folder yang sama dengan project jupyter notebook
#Kedua, panggil data dengan fungsi read
bunga_iris_csv = pd.read_csv("bunga_iris.csv")
bunga_iris_csv
#tanpa mnggunakan perintah print, hasilnya akan lebih rapi
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ***5.21.2 Properti pada Pandas***
#
# Pandas memiliki beberapa properti untuk memudahkan melakukan observasi
# awal tentang data yang baru dipanggil.

# %%
#menggunakan fungsi head
#Gunakan fungsi head () untuk memanggilkan beberapa data pertama
print(bunga_iris_csv.head(5))
#Output yang dihasilkan adalah baris dengan indeks ke-0 sampai dengan 4
#atau 5 baris pertama dalam data
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
print(bunga_iris_csv.head())
#hasilnya akan sama dengan menggunakan fungsi head(5)
#Apabia kita tidak mengisi angka dalam fungsi head(), sistem akan menunjukkan 5 data pertama dalam data bunga_iris
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
bunga_iris_csv.head(6)
#tanpa menggunakan perintah print akan terlihat lebih rapi
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4

# %%
#menggunakan fungsi columns
#digunakan untuk menampilkan daftar nama kolom dalam sebuah data
#Ini berguna untuk memastikan bahwa data telah terbaca dengan benar dan untuk memahami struktur data yang digunakan dalam analisis lebih lanjut.
bunga_iris_csv.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
#fungsi mencetak beberapa data
#Mencetak data yang diinginkan
bunga_iris_csv["sepal length (cm)"]
#dengan menggunakan perintah diatas, sistem kan mencetak semua nilai yang berada dalam kolom 'sepal length (cm)'
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length (cm), Length: 150, dtype: float64

# %%
bunga_iris_csv["petal width (cm)"]
#dengan menggunakan perintah diatas, sistem kan mencetak semua nilai yang berada dalam kolom 'petal width (cm)'
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal width (cm), Length: 150, dtype: float64

# %%
bunga_iris_csv["sepal length (cm)"][1]
bunga_iris_csv["sepal length (cm)"][3]
#dengan menambahkan indeks di belakang nama kolom, sistem akan menunjukkan nilai dari baris dari kolom yang diinginkan
#pada kode ini sistem akan mengambil data pada baris ke-4 pada kolom sepal length (cm)
#karena kode tanpa perintah print, maka hasil luarannya hanya hasil kode yang terakhir
# Out:
# 4.6

# %%
print(bunga_iris_csv["sepal length (cm)"][5])
#pada kode ini sistem akan mengambil data pada baris ke-6 pada kolom sepal length (cm)
print(bunga_iris_csv["sepal length (cm)"][1:5])
#dengan menambahkan batas di belakang nama kolom, sistem akan menampilkan data ada baris tertentu yang berada dalam kolom yang diinginkan
#pada kode ini, sistem akan mencetak nilai pada baris ke-2 hingga ke-4 dari kolom 'sepal length (cm)'
#karena menggunakan perintah print, maka hasil yang keluar adalah hasil dari kedua kode
# Out:
# 5.4
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal length (cm), dtype: float64

# %%
bunga_iris_csv[["sepal length (cm)", "sepal width (cm)"]] [0:5]
#Perintah diatas akan menampilkan nilai pada kolom 'petal length (cm)' dan 'sepal width (cm)'
#dari baris ke 1 atau indeks ke 0 sampai ke 5 atau indeks ke 4 dari data bunga_iris
# Out:
#    sepal length (cm)  sepal width (cm)
# 0                5.1               3.5
# 1                4.9               3.0
# 2                4.7               3.2
# 3                4.6               3.1
# 4                5.0               3.6

# %%
#menggunakan fungsi iloc()
#Mencetak beberapa data
print(bunga_iris_csv.iloc[1])
#fungsi print untuk mencetak baris ke-2 atau indeks 1 dari data set bunga iris yang telah ternuat dalam variabel
print(" ")
print(bunga_iris_csv.iloc[5])
#fungsi print untuk mencetak baris ke-6 atau indeks ke-5 dari data set bunga iris yang telah ternuat dalam variabel
print(" ")
print(bunga_iris_csv.iloc[0:5])
#fungsi ini sama seperti fungsi diatas akan mencetak baris ke 1 sammpai sampai baris ke 5 dari data bunga iris
# Out:
# sepal length (cm)    4.9
# sepal width (cm)     3.0
# petal length (cm)    1.4
# petal width (cm)     0.2
# Name: 1, dtype: float64
#
# sepal length (cm)    5.4
# sepal width (cm)     3.9
# petal length (cm)    1.7
# petal width (cm)     0.4
# Name: 5, dtype: float64
#
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
bunga_iris_csv.iloc[1]
print(" ")
bunga_iris_csv.iloc[5]
print(" ")
bunga_iris_csv.iloc[0:5]
#hasil yang keluar adalah hasil dari kode terakhir karena tidak menggunakan perintah print
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
#menggunakan fungsi loc ()
#mengelompokkan atau memfilter baris pada data frame
(bunga_iris_csv.loc[bunga_iris_csv['sepal width (cm)']== 3.5]) 
#outputnya adalah mendapatkan subset dari dataset 'bunga_iris_csv' dengan isi baris-baris
#baris-baris tersebut berisi nilai pada kolom 'sepal width (cm)' sama dengan 3.5
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                 5.1               3.5                1.4               0.2
# 17                5.1               3.5                1.4               0.3
# 27                5.2               3.5                1.5               0.2
# 36                5.5               3.5                1.3               0.2
# 40                5.0               3.5                1.3               0.3
# 43                5.0               3.5                1.6               0.6

# %% [markdown]
# ***5.21.3 Mengurutkan data pada Pandas***
#
# Data yang telah dipanggil dapat diurutkan mulai dari tinggi ke rendah atau sebaliknya

# %%
#menggunakan fungsi sort.values()
bunga_iris_csv.sort_values("sepal length (cm)")
#perintah 'sort.values' akan mengurutkan baris dari terkecil ke yang terbesar (ascending) berdasarkan nilai dari kolom 'sepal length (cm)'
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 13                 4.3               3.0                1.1               0.1
# 42                 4.4               3.2                1.3               0.2
# 38                 4.4               3.0                1.3               0.2
# 8                  4.4               2.9                1.4               0.2
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 122                7.7               2.8                6.7               2.0
# 118                7.7               2.6                6.9               2.3
# 117                7.7               3.8                6.7               2.2
# 135                7.7               3.0                6.1               2.3
# 131                7.9               3.8                6.4               2.0
#
# [150 rows x 4 columns]

# %%
bunga_iris_csv.sort_values("petal width (cm)")
#perintah 'sort.values' akan mengurutkan baris dari terkecil ke yang terbesar (ascending) berdasarkan nilai dari kolom 'petal width(cm)'
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 32                 5.2               4.1                1.5               0.1
# 13                 4.3               3.0                1.1               0.1
# 37                 4.9               3.6                1.4               0.1
# 9                  4.9               3.1                1.5               0.1
# 12                 4.8               3.0                1.4               0.1
# ..                 ...               ...                ...               ...
# 140                6.7               3.1                5.6               2.4
# 114                5.8               2.8                5.1               2.4
# 100                6.3               3.3                6.0               2.5
# 144                6.7               3.3                5.7               2.5
# 109                7.2               3.6                6.1               2.5
#
# [150 rows x 4 columns]

# %%
bunga_iris_csv.sort_values(["sepal length (cm)","petal width (cm)"])
#dengan menggunakan perintah ini dapat mengurutkan baris dalam data berdasarkan nilai dari beberapa kolom yang telah ditentukan
#Dalam data ini kita akan mengurutkan baris dalam data bunga iris berdasarkan nilai pada kolom 'sepal length (cm)' terlebih dahulu 
#Kemudian, untuk baris yang mimiliki nilai yang sama pada kolom 'sepal length(cm)' akan diurutkan berdasarkan nilai pada kolom 'petal length (cm)' 
#semua pengurutan dari yang terkecil ke terbesar
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 13                 4.3               3.0                1.1               0.1
# 8                  4.4               2.9                1.4               0.2
# 38                 4.4               3.0                1.3               0.2
# 42                 4.4               3.2                1.3               0.2
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 122                7.7               2.8                6.7               2.0
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 135                7.7               3.0                6.1               2.3
# 131                7.9               3.8                6.4               2.0
#
# [150 rows x 4 columns]

# %%
bunga_iris_csv.sort_values("sepal length (cm)", ascending=False)
#menggunakan parameter 'ascending=False' untuk mengurutkan baris dari nilai terbesar ke terkecil bedasarkan nilai dari kolom tertentu
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 131                7.9               3.8                6.4               2.0
# 135                7.7               3.0                6.1               2.3
# 122                7.7               2.8                6.7               2.0
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# ..                 ...               ...                ...               ...
# 41                 4.5               2.3                1.3               0.3
# 42                 4.4               3.2                1.3               0.2
# 38                 4.4               3.0                1.3               0.2
# 8                  4.4               2.9                1.4               0.2
# 13                 4.3               3.0                1.1               0.1
#
# [150 rows x 4 columns]

# %%
bunga_iris_csv.sort_values(["sepal length (cm)", "petal width (cm)"], ascending=False)
#dengan menggunakan perintah ini dapat mengurutkan baris dalam data berdasarkan nilai dari beberapa kolom yang telah ditentukan
#Dalam data ini kita akan mengurutkan baris dalam data bunga iris berdasarkan nilai pada kolom 'sepal length (cm)' terlebih dahulu 
#Kemudian, untuk baris yang mimiliki nilai yang sama pada kolom 'sepal length(cm)' akan diurutkan berdasarkan nilai pada kolom 'petal length (cm)' 
#semua pengurutan dari yang terbesar ke terkecil
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 131                7.9               3.8                6.4               2.0
# 118                7.7               2.6                6.9               2.3
# 135                7.7               3.0                6.1               2.3
# 117                7.7               3.8                6.7               2.2
# 122                7.7               2.8                6.7               2.0
# ..                 ...               ...                ...               ...
# 41                 4.5               2.3                1.3               0.3
# 8                  4.4               2.9                1.4               0.2
# 38                 4.4               3.0                1.3               0.2
# 42                 4.4               3.2                1.3               0.2
# 13                 4.3               3.0                1.1               0.1
#
# [150 rows x 4 columns]

# %% [markdown]
# ***5.21.4 Mengubah data pada Pandas***

# %%
#menambah kolom
bunga_iris_csv["Jumlah lebar sepal besar"] = 1.5*bunga_iris_csv["sepal width (cm)"]
bunga_iris_csv
#kode diatas menumberi instruksi bahwa kita akan menambahkan kolom baru pada data set.
#dengan nama kolom barunya "Jumlah lebar sepal besar"
#nilainya akan dihitung sebagai sepal width (cm) dikalikan dengan 1.5 (angka coba-coba)
#ketika dijalankan akan data akan memiliki sebuah kolom baru dengan nama"Jumlah lebar sepal besar"
#nilainya setaraa denagan 1.5 kali pada kolom 'sepal width (cm)' di setiap barisnya
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Jumlah lebar sepal besar
# ...

# %%
#menggunakan fungsi drop
#menghapus kolom
bunga_iris_csv = bunga_iris_csv.drop(columns=["Jumlah lebar sepal besar"])
bunga_iris_csv
#Ketika kode tersebut dieksekusi, fungsi drop akan menghapus kolom yang telah ditentukan dengan argumen 'columns'
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
bunga_iris_csv['Perbandingan setal'] = bunga_iris_csv ['sepal length (cm)'] // bunga_iris_csv['sepal width (cm)']
bunga_iris_csv
#Kode diatas akan membuat kolom baru pada Data bunga iris yang akan dinamai 'Perbandingan setal'
#Kolom tersebut berisi hasil pembagian yang telah dibulatkan antara nilai kolom 'setal length (cm)' dengan kolom 's etal width (cm)'
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Perbandingan setal
# ...

# %%
bunga_iris_csv["Jumlah lebar sepal"] = bunga_iris_csv.iloc[:,3:5].sum(axis=1)
bunga_iris_csv
#Kode diatas akan menghitung jumlah kolom ke-3 hingga kolom ke-5 pada objek DataFrame Pandas dari 'bunga_iris'
#hasil akan ditempatkan pada kolom bernama jumlah lebar sepal pada data frame yang sama
#dilskuksn pencetakan sehingga kolom baru jumlah lebar sepal berisi jumlah nilai dari kolom ke-3 hingga ke-5 pada setiap baris dari data Frame
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Jumlah lebar sepal
# ...

# %%
bunga_iris_csv['sepal length (cm)'] = bunga_iris_csv['sepal length (cm)'].replace(['None'], 5.0)
bunga_iris_csv
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Jumlah lebar sepal
# ...

# %% [markdown]
# ***5.21.5 Menyimpan data menggunakan Pandas***
#
# Data yang telah dirubah sesuai dengan keperluan dapat disimpan menjadi tiga
# bentuk file yaitu .txt, .xlsx dan .csv.

# %%
bunga_iris_csv.to_csv("bunga_iris_baru.txt",index=False, sep = "\t")
#Menyimpan dengan format .txt
#pada kode diatas, metode 'to_csv' dipanggil dengan 3 parameter
#'bunga_iris_baru.txt' sebagai nama dari file 
#'index=False' untuk mengecualikan index dari DataFrame pada output file
#'sep='\t' sebagai pemisah kolom (delimiter) antara nilai-nilau dalam daya frame. Pada kasus ini, pemisah kolom yang digunakan adalah tanda tab ('\t')
#Dengan menjalankan kode diatas, file akan tersimpan dalam direktori kerja dengan nilai-nilai dari DataFrame telah diubah dan diproses

# %%
bunga_iris_csv.to_csv("bunga_iris_baru.csv",index=False)
#Menyimpan dengan format .csv

# %%
bunga_iris_csv.to_excel('bunga_iris_baru.xlsx', index=False)
#Menyimpan dengan format .xlsx
#pada kode diatas, metode 'to_csv' dipanggil dengan 2 parameter
#'bunga_iris_baru.xlsx' sebagai nama dari file output
#'index=False' untuk mengecualikan index dari DataFrame pada output file
#Dengan menjalankan kode diatas, file akan tersimpan dalam direktori kerja dengan nilai-nilai dari DataFrame telah diubah dan diproses

# %%
#menampilkan data
iris_baru = pd.read_excel('bunga_iris_baru.xlsx')
iris_baru
#Kode diatas digunakan untuk membaca file terbaru yang telah disimpan sebelumnya menggunakan metode 'read_excel()'
#karena telah dilakukan beberapa prose pengolahan sebelumnya, kemungkinan nilai-nilai dalam 'bunga_baru' akan berbeda dengan nilai awal dari bunga_iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Jumlah lebar sepal
# ...

# %%
iris_baru1 = pd.read_csv("bunga_iris_baru.txt")
iris_baru1
#bandingkan dengan kode yang dibawah
# Out:
#     sepal length (cm)\tsepal width (cm)\tpetal length (cm)\tpetal width (cm)\tJumlah lebar sepal
# 0               5.1\t3.5\t1.4\t0.2\t0.6000000000000001
# 1               4.9\t3.0\t1.4\t0.2\t0.6000000000000001
# 2               4.7\t3.2\t1.3\t0.2\t0.6000000000000001
# 3               4.6\t3.1\t1.5\t0.2\t0.6000000000000001
# 4               5.0\t3.6\t1.4\t0.2\t0.6000000000000001
# ..                                                 ...
# 145             6.7\t3.0\t5.2\t2.3\t6.8999999999999995
# 146              6.3\t2.5\t5.0\t1.9\t5.699999999999999
# 147                            6.5\t3.0\t5.2\t2.0\t6.0
# 148             6.2\t3.4\t5.4\t2.3\t6.8999999999999995
# 149                            5.9\t3.0\t5.1\t1.8\t5.4
#
# [150 rows x 1 columns]

# %%
#bandingkan dengan kode yang diatas
iris_baru2 = pd.read_csv ('bunga_iris_baru.txt',delimiter='\t')
iris_baru2
#Kode diatas digunakan untuk membaca file dengan menggunakan fungsi 'read_csv()'dari Pandas dan menyimpannya ke dalam DataFrame baru 'bunga_baru2'
#Parameter 'delimiter='\t' digunakan untuk menunjukkan bahwa delimiter dalam file yang dibaca adalah tab ('\t')
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ***5.21.6 Menyaring data menggunakan Pandas***
#
# Data yang telah dipanggil dapat disaring sesuai dengan kebutuhan analisis kedepannya.

# %%
#fungsi loc
bunga_iris_csv.loc[bunga_iris_csv["sepal length (cm)"]== 4.8]
#digunakan untuk mencari baris di DataFrame 'bunga_iris' yang memiliki nilai kolom 'sepal length (cm)' = 4.8 menggunakan metode '.loc[]'
#Dengan menjalankan kode diatas, baris dengan nilai kolom 'sepal length(cm)' = 4.8 akan ditampilkan. 
#Jika tidak ada baris yang sesuai, tidak akan ada data yang ditampilkan
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 11                4.8               3.4                1.6               0.2
# 12                4.8               3.0                1.4               0.1
# 24                4.8               3.4                1.9               0.2
# 30                4.8               3.1                1.6               0.2
# 45                4.8               3.0                1.4               0.3

# %%
bunga_iris_csv.loc[bunga_iris_csv["sepal length (cm)"]== 1.1]
#tidak ada baris yang sesuai, tidak akan ada data yang ditampilkan
# Out:
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm)]
# Index: []

# %%
bunga_iris_csv.loc[(bunga_iris_csv['sepal length (cm)']== 5.0) &
                (bunga_iris_csv['petal width (cm)'] == 0.2)]
#Kode ini digunakan untuk mencari baris DataFrame 'bunga_iris' yang memiliki nilai 'sepal length (cm) ' = 5.0
#dan kolom 'petal width(cm)' = 0.2 dengan metode '.loc[]'serta operator logika 'dan' atau &
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 4                 5.0               3.6                1.4               0.2
# 7                 5.0               3.4                1.5               0.2
# 25                5.0               3.0                1.6               0.2
# 35                5.0               3.2                1.2               0.2
# 49                5.0               3.3                1.4               0.2

# %%
bunga_iris_csv.loc[(bunga_iris_csv['sepal length (cm)']== 5.0) &
                (bunga_iris_csv['petal width (cm)'] == 0.2) &
                (bunga_iris_csv['sepal width (cm)'] == 3.3)]
#baris yang memenuhi syarat akan ditampilkan oleh sistem
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 49                5.0               3.3                1.4               0.2

# %% [markdown]
# ***5.21.7 Pengelompokan data menggunakan Pandas***
#
# Data yang sama dapat dikelompokkan untuk analisis lebih lanju

# %%
#menggunakan fungsi metode.groupby
#menggunakan fungsi perintah .mean
bunga_iris_csv.groupby(["sepal length (cm)"]).mean()
#metode 'groupby()'untuk mengelompokkan baris di Data Frame berdasarkan nilai dari kolom 'sepal width(cm)'
#'mean()' untuk menghitung nilai rata-rata dari setiap kelompok
#Ketika kode diatas dijalankan, akan dihasilkan suatu data bru yang berisi nilai rata-rata dari setiap kolom 'bunga iris' yg sudah dikelompokkan berdasarkan nilai kolom 'sepal width (cm)'
# Out:
#                    sepal width (cm)  petal length (cm)  petal width (cm)
# sepal length (cm)
# 4.3                        3.000000           1.100000          0.100000
# 4.4                        3.033333           1.333333          0.200000
# 4.5                        2.300000           1.300000          0.300000
# 4.6                        3.325000           1.325000          0.225000
# 4.7                        3.200000           1.450000          0.200000
# 4.8                        3.180000           1.580000          0.200000
# 4.9                        2.950000           2.266667          0.550000
# 5.0                        3.120000           1.840000          0.430000
# 5.1                        3.477778           1.722222          0.400000
# 5.2                        3.425000           2.075000          0.475000
# 5.3                        3.700000           1.500000          0.200000
# 5.4                        3.550000           2.033333          0.516667
# ...

# %%
bunga_iris_csv.groupby(["sepal length (cm)"]).mean().sort_values("petal width (cm)",ascending=True)
#metode 'groupby()' untuk mengelompokkan baris dalam DataFrame berdasaekan nilai 'sepal length(cm)'
#metode 'mean()' untuk menghitung rata-rata dari setiap kelompok.
#metode 'sort_values()' untuk mengurutkan data hasil kelompokkan berdasarkan kolom 'petal width (cm)' secara menaik
#ketika kode tersebut dijalankan, output yang dihasilkan adalah data baru yang berisi 
#nilai rata-rata dar setiap kolom yang sudah dikelompokkan berdasarkan nilai pada kolom 'sepal length (cm)
#Kemudian, data diurutkan berdasarkan kolom 'petal width (cm)' secara menaik
# Out:
#                    sepal width (cm)  petal length (cm)  petal width (cm)
# sepal length (cm)
# 4.3                        3.000000           1.100000          0.100000
# 4.7                        3.200000           1.450000          0.200000
# 4.8                        3.180000           1.580000          0.200000
# 5.3                        3.700000           1.500000          0.200000
# 4.4                        3.033333           1.333333          0.200000
# 4.6                        3.325000           1.325000          0.225000
# 4.5                        2.300000           1.300000          0.300000
# 5.1                        3.477778           1.722222          0.400000
# 5.0                        3.120000           1.840000          0.430000
# 5.2                        3.425000           2.075000          0.475000
# 5.4                        3.550000           2.033333          0.516667
# 4.9                        2.950000           2.266667          0.550000
# ...

# %%
#perintah sum()
bunga_iris_csv.groupby(["sepal width (cm)"]).sum()
#pada kode diatas dilakukan suatu pengelompokkan data pada variabel bunga_iris berdasarkan kolom 'sepal width (cm)'
#Selanjutnya dilakukan agregasi nilai dengan fungsi 'sum()' 
#dimana untuk setiap kelompok data yang dihasilkan dari pengelompokkan tersebut
#Output yang dihasilkan adalah suatu data hasil penjumlahan untuk setiap kolom dari data bunga_iris 
#dengan perhitungannya berdasarkan kelompok-kelompok yang dibentuk berdasarkan nilai unik pada kolom 'sepal width(cm)'
# Out:
#                   sepal length (cm)  petal length (cm)  petal width (cm)
# sepal width (cm)
# 2.0                             5.0                3.5               1.0
# 2.2                            18.2               13.5               4.0
# 2.3                            21.3               13.0               3.9
# 2.4                            15.9               10.8               3.1
# 2.5                            46.1               36.1              12.4
# 2.6                            30.8               24.4               7.1
# 2.7                            52.7               41.6              14.0
# 2.8                            88.7               70.6              23.9
# 2.9                            60.6               43.5              13.2
# 3.0                           156.4              110.1              36.5
# 3.1                            66.4               41.7              13.7
# 3.2                            76.5               48.8              16.4
# ...

# %%
#perintah .count()
bunga_iris_csv.groupby(["petal width (cm)"]).count()
#perintah grupby() digunakan untuk mengelompokkan data berdasaekan nilai unik pada suatu kolom yaitu 'petal width (cm)'
#perintah count() digunakan untuk menghitung jumlah entri data pada setiap kelompok
#hasil yang dikeluarkan adalah jumlah entri data pada setiap nilai unik pada kolom 'petal width (Cm)'
# Out:
#                   sepal length (cm)  sepal width (cm)  petal length (cm)
# petal width (cm)
# 0.1                               5                 5                  5
# 0.2                              29                29                 29
# 0.3                               7                 7                  7
# 0.4                               7                 7                  7
# 0.5                               1                 1                  1
# 0.6                               1                 1                  1
# 1.0                               7                 7                  7
# 1.1                               3                 3                  3
# 1.2                               5                 5                  5
# 1.3                              13                13                 13
# 1.4                               8                 8                  8
# 1.5                              12                12                 12
# ...

# %% [markdown]
# # ***5.22 Matplotlib***
#
# Matplotlib merupakan salah satu Library pada Python yang fungsi utamanya
# adalah dalam hal menggambarkan grafik, histogram dan berbagai jenis plot hasil
# dari pengolahan data menggunakan Library lainnya yaitu Pandas dan Numpy.

# %% [markdown]
# Pemanggilan library

# %%
import numpy as np
#numpy adalah library untuk pemrosesan multidimensi dan operasi matematika

# %%
import pandas as pd
#Pandas adalah library untuk mengelola dan menganalisis data dalam format tabel

# %%
import matplotlib.pyplot as plt
#Matplotlib adalah library untuk membuat visualisasi grafik dan plot

# %% [markdown]
# ***5.22.1 Grafik sederhana dengan Matplotlib***

# %%
a = [1,2,3]
b = [2,4,6]
plt.plot (a,b)
#metode plot digunakan untuk menggambar garis yang menghubungkan ketiga titik yaitu (1,2), (2,4), dan (3,6) pada bidang koordinat
plt.title ("Grafik b = 2a")
#tittle digunakan untuk memberikan judul grafik yaitu grafik b = 2a
plt.xlabel ('a')
#kemudian, sumbu x diberi label dengan kode seperti diatas
plt.ylabel ('b')
#kemudian, sumbu y diberi label dengan kode seperti diatas
# Out:
# Text(0, 0.5, 'b')

# %% [markdown]
# ***5.22.2 Properti Pembuatan Grafik dengan Matplotlib***

# %%
#diinisialisasikan variabel x dan y yang merupakan list yang berisi 9 nilai dari masing-masing variabel x dan y yang berkaitan dengan fungsi y = x^3
x = [-4,-3,-2,-1,0,1,2,3,4]
y = [16,9,4,1,0,1,4,9,16]
#Kemudian, diinisialisasikan juga variabel x1 dan y1 yang juga merupakan list yang berisi masing-masing anggota dari variabel x1 dan y1 
x1 = [1,2,3,4,5,6,7]
y1 = [-2,0,2,4,6,8,10]

#menentukan ukuran dan resolusi gambar
plt.figure(figsize=(2,2), dpi =300)
#figsize digunakan untuk menentukan gambar dengan format inci. sehingga pada kode ini ukuran gambar yang akan dihasilkan adalah 2x2 inci
#dpi digunakan untuk menentukan resolusi gambar dalam piksel per inci. Sehingga, pada kode ini resolusi yang dihasilkan adalah 300 piksel per inci

#Kemudian ditentukan font, ukuran font, serta warna dari garis dan grafik
plt.plot(x,y,label='y=x^2',color='blue',linewidth=3,marker='.',markersize =10,markeredgecolor='purple',linestyle='-')
#label='y=x^2' : dugunakan untuk memberi label atau judul pada plot
#color : digunakan untuk memberi warna pada plot
#linewidth : digunakan untuk memberi ketebalan garis pada plot
#marker : digunakan untuk menandai titik pada plot dengan bentuk titik
#markersize : digunakan untuk menentukan ukuran dari marker
#markerredgecolor : digunakan untuk memberi warna pada tepi marker
#linestyle : digunakan untuk menentukan jenis garis pada plot
plt.plot(x1,y1)
#metode ini digunakan untuk membuat plot dari data pada variabel x1 dan y1
#plot ini tidak memiliki variabel lain seperti label ataupun color sehingga plot ini akan menggunakan nilai default untuk setiap parameter
plt.title ('Grafik y =x^2', fontdict={'fontname' : 'Times New Roman', 'fontsize' :14})
#Ditentukan font dan ukuran font pada judul grafik
#'Grafik y =x^3', adalah string yang akan ditampilkan sebagai judul grafik
#fontdict : digunakan untuk mengatur jenis font dan ukuran font dari judul grafik
#fontname : jenis fnt
#fontsize : ukuran font
plt.xlabel ('x', fontdict={'fontname':'Comic Sans MS','fontsize':14})
plt.ylabel ('y', fontdict={'fontname':'Comic Sans MS','fontsize':14})
#Kemudian, sumbu x dan y diberi label pada grafik
plt.xticks ([-4,-3,-2,-1,0,1,2,3,4])
plt.yticks ([16,9,4,1,0,1,4,9,16])
#Digunakan fungsi plt.ticks untuk menentukan skala sumbu x dan t yang akan ditampilkan pada grafik
#pada sumbu x ditampilkan angka dari -4 sampai 4
#pada sumbu y ditampilkan angka dari 16 sampai 16
plt.legend()
#metode ini digunakan untuk menampilkan legenda pada grafik yang menunjukkan label garis untuk grafik pertaman
plt.savefig('grafik.png', dpi=300)
#metode ini digunakan untuk menyimpan grafik sebagai file gambar dalam format PNG dan nama Grafik "grafik.png" dengan resolusi 300dpi
plt.show()
#Metode ini digunakan untuk menampilkan grafik pada jendela hasil
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# ...

# %%
# diinisialisasikan variabel-variabel yang berisi data kolom pada dataFrame bunga_iris
x = bunga_iris_csv['sepal length (cm)']
y = bunga_iris_csv['petal length (cm)']
x1 = bunga_iris_csv['sepal width (cm)']
y1 = bunga_iris_csv['petal width (cm)']


plt.figure(figsize=(12,12), dpi=300)
#figsize digunakan untuk menentukan gambar dengan format inci. sehingga pada kode ini ukuran gambar yang akan dihasilkan adalah 12x12 inci
#dpi digunakan untuk menentukan resolusi gambar dalam piksel per inci. Sehingga, pada kode ini resolusi yang dihasilkan adalah 300 piksel per inci



plt.plot(x,y, label = 'Grafik length' ,  color = 'green' , 
         linewidth = 2 , marker = '.' , markersize = 15 , 
         markeredgecolor = 'blue' , linestyle='-')
#label='Grafik length' : dugunakan untuk memberi label atau judul pada plot
#color : digunakan untuk memberi warna pada plot
#linewidth : digunakan untuk memberi ketebalan garis pada plot
#marker : digunakan untuk menandai titik pada plot dengan bentuk titik
#markersize : digunakan untuk menentukan ukuran dari marker
#markerredgecolor : digunakan untuk memberi warna pada tepi marker
#linestyle : digunakan untuk menentukan jenis garis pada plot


plt.plot(x1,y1, label = 'Grafik width', marker = '*' , 
         markersize = 15 , markeredgecolor = 'red' )
#metode ini digunakan untuk membuat plot dari data pada variabel x1 dan y1
#plot ini tidak memiliki variabel lain seperti label ataupun color sehingga plot ini akan menggunakan nilai default untuk setiap parameter

# berikut penamaan koordinat dengan fungsi 'title()'
# fungsi 'title()' digunakan untuk memasukan data string dan ukuran font
# fungsi 'fontdict' digunakan untuk menentukan ukuran font
plt.title('Grafik Bunga Iris ', fontdict = {'fontname' : 'Times New Roman' , 'fontsize' : 12})

# berikut inisialisasi sumbu x dan y dengan penamaan menggunakan data string
# fungsi 'fontdict' digunakan untuk menentukan ukuran font
plt.xlabel('X', fontdict={'fontname' : 'Comic Sans MS' , 'fontsize' : 6})
plt.ylabel('Y', fontdict={'fontname' : 'Comic Sans MS' , 'fontsize' : 6})

# berikut pembentukan output dari label x dan y
plt.xticks(bunga_iris_csv['sepal length (cm)'])
plt.yticks(bunga_iris_csv['petal length (cm)'])
plt.legend()

# berikut pembentukan output dari label x1 dan y1
plt.xticks(bunga_iris_csv['sepal width (cm)'])
plt.yticks(bunga_iris_csv['petal width (cm)'])
plt.legend()

# berikut penyimpanan figure pada 'grafik.png' dengan resolusi 300 dpi
plt.savefig('grafik.png' , dpi=300)

# berikut fungsi 'show()' yang digunakan untuk mengeluarkan output figure
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# ...

# %% [markdown]
# ***5.22.3 Histogram sederhana dengan Matplotlib***

# %%
#plt.bar adalah metode pada library matplotlib yang digunakan untuk membuat histogram
bangtan = ['RM', 'Jin','Suga', 'J Hope', 'Jimin', 'V', 'Jungkook']
#diinisialisasikan juga list yang berisi nilai dari data yang akan ditampilkan pada sumbu y dan panjang dari setiap bar
tinggi = [175, 173, 172, 173, 170, 173,173]

#metode plt.bar akan menampilkan bar chart dengan sumbu x berisi label dari variabel pengguna 
#serta variabel y menampilkan nilai dari jumlah
plt.bar(bangtan,tinggi)
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# ***5.22.4 Properti Pembuatan Histogram dengan Matplotlib***

# %%
#Properti pembuatan Histogram
#Diinisialisasikan variabel idol kpop BTS yang berisi list untuk menjadi label pada sumbu x
bangtan = ['RM', 'Jin','Suga', 'J Hope', 'Jimin', 'V', 'Jungkook']
#diinisialisasikan juga variabel tinggi sebagai nilai pada sumbu y
tinggi = [175, 173, 172, 173, 170, 173,173]

#digunakan method "plt.figure" untuk menentukan ukuran dan resolusi gambar
plt.figure(figsize=(10,5))
#figsize digunakan untuk menentukan gambar dengan format inci. sehingga pada kode ini ukuran gambar yang akan dihasilkan adalah 10x5 inci
hist = plt.bar(bangtan,tinggi,color = 'purple')
#Selanjutnya kita memanggil metode untuk membuat histogram
#variabel hist sebagai objek dari diagram batang tersebut
#Kita juga dapat menentukan warna pada histogram dengan menambahan parameter color
#Variabel hist berisi sebuah list yang berisi bar chart yang telah dibuat.
pola = ['/','/','/','*','*','*','*']
#Kita juga dapat membuat sebuah list 'pola' yang berisi simbol-simbol yang digunakan sebagai pola pada bar chart
for bar in hist :
#digunakan loop 'for' untuk mengakses setiap bar pada histogram variabel hist
    bar.set_hatch(pola.pop(0))
#pada setiap bar, diatur pola dengan menggunakan set_hatch dan pola.pop(0)
#pola.pop(0) digunakan untuk mengambil dan menghapus elemen pertama dari list pola sehingga setiap bar akan memiliki pola yang berbeda
plt.show()
#kode diatas dipanggil untuk menampilkan histogram yang telah dibuat

# %%
import pandas as pd
import matplotlib.pyplot as plt
# membaca file data iris
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', 
                 names=['sepal length', 'sepal width', 'petal length', 'petal width', 'class'])

# menampilkan lima data pertama dari dataframe
print(df.head(9))

# menghitung nilai rata-rata setiap variabel untuk setiap jenis bunga iris
df_mean = df.groupby(['class']).mean()
print(df_mean)

# membuat plot scatter untuk melihat persebaran bunga iris berdasarkan panjang dan lebar kelopak bunga
plt.scatter(df[df['class']=='Iris-setosa']['sepal length'], df[df['class']=='Iris-setosa']['sepal width'], 
            color='green', label='Iris-setosa')
plt.scatter(df[df['class']=='Iris-versicolor']['sepal length'], df[df['class']=='Iris-versicolor']['sepal width'], 
            color='red', label='Iris-versicolor')
plt.scatter(df[df['class']=='Iris-virginica']['sepal length'], df[df['class']=='Iris-virginica']['sepal width'], 
            color='blue', label='Iris-virginica')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title('Scatter plot of Iris dataset')
plt.legend()
plt.show()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
#                  sepal length  sepal width  petal length  petal width
# class
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# ...
